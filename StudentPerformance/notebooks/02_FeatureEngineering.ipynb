# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sys
sys.path.append('../notebooks')

from utils import load_student_data

df = load_student_data()

# Plot score destribution
plt.figure(figsize=(10, 6))
df[['math score', 'reading score', 'writing score']].hist(bins=20)
plt.suptitle("Score Distributions")
plt.tight_layout()
plt.show()

# Gender-wise score distribution
df['average score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)
sns.boxplot(x='gender', y='average score', data=df)
plt.title('Average Score by Gender')
plt.show()

# %%
# Corelation Analysis
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Distribution by Groups
## Gender vs. Group
sns.boxplot(x='gender', y='math score', data=df)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
## Test Prep vs Score:
sns.boxplot(x='test preparation course', y='math score', data=df)
# Out:
# <Axes: xlabel='test preparation course', ylabel='math score'>

# %%
## Parental Education vs Total Score:
plt.figure(figsize=(10,5))
sns.barplot(x='parental level of education', y='average score', data=df)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
# Categorize Performance Levels
df['performance_level'] = pd.cut(df['average score'], bins=[0,60,80,100], labels=['Low','Medium','High'])
sns.countplot(x='performance_level', hue='gender', data=df)
# Out:
# <Axes: xlabel='performance_level', ylabel='count'>
